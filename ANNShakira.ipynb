# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report

# %%
df = pd.read_csv('/content/car_purchasing.csv', encoding='ISO-8859-1')
df.head()
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# 2  638467.1773          42925.70921
# 3  548599.0524          67422.36313
# 4  560304.0671          55915.46248

# %%
df.drop(columns=['customer name', 'customer e-mail', 'country', 'gender'], inplace=True)

# %%
df.head()
# Out:
#          age  annual Salary  credit card debt    net worth  \
# 0  41.851720    62812.09301      11609.380910  238961.2505
# 1  40.870623    66646.89292       9572.957136  530973.9078
# 2  43.152897    53798.55112      11160.355060  638467.1773
# 3  58.271369    79370.03798      14426.164850  548599.0524
# 4  57.313749    59729.15130       5358.712177  560304.0671
#
#    car purchase amount
# 0          35321.45877
# 1          45115.52566
# 2          42925.70921
# 3          67422.36313
# 4          55915.46248

# %%
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 5 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   age                  500 non-null    float64
#  1   annual Salary        500 non-null    float64
#  2   credit card debt     500 non-null    float64
#  3   net worth            500 non-null    float64
#  4   car purchase amount  500 non-null    float64
# dtypes: float64(5)
# memory usage: 19.7 KB
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
plt.scatter(df['annual Salary'] , df['credit card debt'])
plt.xlabel('annual Salary')
plt.ylabel('credit card debt')
plt.title('the corr between credit card debt and annual Salary')
# Out:
# Text(0.5, 1.0, 'the corr between credit card debt and annual Salary')

# %%
sns.pairplot(df)

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]

# %%
scale = MinMaxScaler()
X = scale.fit_transform(X)
y = scale.fit_transform(y.values.reshape(-1, 1))
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2)

# %%
#Trying linear regression
lreg = LinearRegression()
lreg.fit(X_train, y_train)
print('Train score', lreg.score(X_train, y_train))
print('Test score', lreg.score(X_test, y_test))
# Out:
# Train score 0.9999999818237372
# Test score 0.999999977254054

# %%
y_pred = lreg.predict(X_test)

# %%
ann = Sequential([Dense(32, activation="relu"),
                 Dense(1, activation='linear')])

ann.compile(optimizer='adam',
            loss='mean_squared_error',
            metrics=['mean_absolute_error'])


history = ann.fit(X_train, y_train, epochs=50, validation_split=0.2)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 1s 59ms/step - loss: 0.0709 - mean_absolute_error: 0.2346 - val_loss: 0.0409 - val_mean_absolute_error: 0.1610
# Epoch 2/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0243 - mean_absolute_error: 0.1244 - val_loss: 0.0162 - val_mean_absolute_error: 0.1002
# Epoch 3/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0126 - mean_absolute_error: 0.0893 - val_loss: 0.0156 - val_mean_absolute_error: 0.1034
# Epoch 4/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0127 - mean_absolute_error: 0.0908 - val_loss: 0.0139 - val_mean_absolute_error: 0.0977
# Epoch 5/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0104 - mean_absolute_error: 0.0809 - val_loss: 0.0111 - val_mean_absolute_error: 0.0849
# Epoch 6/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0087 - mean_absolute_error: 0.0735 - val_loss: 0.0098 - val_mean_absolute_error: 0.0783
# Epoch 7/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0076 - mean_absolute_error: 0.0682 - val_loss: 0.0087 - val_mean_absolute_error: 0.0739
# Epoch 8/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0067 - mean_absolute_error: 0.0641 - val_loss: 0.0078 - val_mean_absolute_error: 0.0704
# Epoch 9/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0061 - mean_absolute_error: 0.0613 - val_loss: 0.0071 - val_mean_absolute_error: 0.0678
# Epoch 10/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0057 - mean_absolute_error: 0.0588 - val_loss: 0.0066 - val_mean_absolute_error: 0.0647
# Epoch 11/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0053 - mean_absolute_error: 0.0567 - val_loss: 0.0062 - val_mean_absolute_error: 0.0619
# Epoch 12/50
# 10/10 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_absolute_error: 0.0551 - val_loss: 0.0058 - val_mean_absolute_error: 0.0604
# Epoch 13/50
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0047 - mean_absolute_error: 0.0536 - val_loss: 0.0055 - val_mean_absolute_error: 0.0587
# Epoch 14/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0044 - mean_absolute_error: 0.0521 - val_loss: 0.0052 - val_mean_absolute_error: 0.0569
# Epoch 15/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_absolute_error: 0.0509 - val_loss: 0.0049 - val_mean_absolute_error: 0.0553
# Epoch 16/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0040 - mean_absolute_error: 0.0496 - val_loss: 0.0046 - val_mean_absolute_error: 0.0545
# Epoch 17/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0038 - mean_absolute_error: 0.0484 - val_loss: 0.0044 - val_mean_absolute_error: 0.0524
# Epoch 18/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0036 - mean_absolute_error: 0.0473 - val_loss: 0.0042 - val_mean_absolute_error: 0.0516
# Epoch 19/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0034 - mean_absolute_error: 0.0461 - val_loss: 0.0040 - val_mean_absolute_error: 0.0496
# Epoch 20/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0032 - mean_absolute_error: 0.0449 - val_loss: 0.0038 - val_mean_absolute_error: 0.0483
# Epoch 21/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0031 - mean_absolute_error: 0.0439 - val_loss: 0.0036 - val_mean_absolute_error: 0.0476
# Epoch 22/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0029 - mean_absolute_error: 0.0427 - val_loss: 0.0034 - val_mean_absolute_error: 0.0459
# Epoch 23/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0028 - mean_absolute_error: 0.0417 - val_loss: 0.0032 - val_mean_absolute_error: 0.0449
# Epoch 24/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0026 - mean_absolute_error: 0.0404 - val_loss: 0.0031 - val_mean_absolute_error: 0.0436
# Epoch 25/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0025 - mean_absolute_error: 0.0393 - val_loss: 0.0029 - val_mean_absolute_error: 0.0424
# Epoch 26/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0023 - mean_absolute_error: 0.0379 - val_loss: 0.0027 - val_mean_absolute_error: 0.0414
# Epoch 27/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0022 - mean_absolute_error: 0.0370 - val_loss: 0.0026 - val_mean_absolute_error: 0.0400
# Epoch 28/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0021 - mean_absolute_error: 0.0359 - val_loss: 0.0024 - val_mean_absolute_error: 0.0389
# Epoch 29/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0019 - mean_absolute_error: 0.0347 - val_loss: 0.0023 - val_mean_absolute_error: 0.0378
# Epoch 30/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0018 - mean_absolute_error: 0.0337 - val_loss: 0.0021 - val_mean_absolute_error: 0.0367
# Epoch 31/50
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0017 - mean_absolute_error: 0.0327 - val_loss: 0.0020 - val_mean_absolute_error: 0.0356
# Epoch 32/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0016 - mean_absolute_error: 0.0315 - val_loss: 0.0019 - val_mean_absolute_error: 0.0346
# Epoch 33/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0015 - mean_absolute_error: 0.0306 - val_loss: 0.0018 - val_mean_absolute_error: 0.0333
# Epoch 34/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0014 - mean_absolute_error: 0.0294 - val_loss: 0.0017 - val_mean_absolute_error: 0.0324
# Epoch 35/50
# 10/10 [==============================] - 0s 10ms/step - loss: 0.0013 - mean_absolute_error: 0.0282 - val_loss: 0.0015 - val_mean_absolute_error: 0.0310
# Epoch 36/50
# 10/10 [==============================] - 0s 7ms/step - loss: 0.0012 - mean_absolute_error: 0.0274 - val_loss: 0.0014 - val_mean_absolute_error: 0.0300
# Epoch 37/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0011 - mean_absolute_error: 0.0263 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 38/50
# 10/10 [==============================] - 0s 8ms/step - loss: 0.0010 - mean_absolute_error: 0.0254 - val_loss: 0.0012 - val_mean_absolute_error: 0.0278
# Epoch 39/50
# 10/10 [==============================] - 0s 6ms/step - loss: 9.4425e-04 - mean_absolute_error: 0.0244 - val_loss: 0.0012 - val_mean_absolute_error: 0.0269
# Epoch 40/50
# 10/10 [==============================] - 0s 8ms/step - loss: 8.6724e-04 - mean_absolute_error: 0.0233 - val_loss: 0.0011 - val_mean_absolute_error: 0.0260
# Epoch 41/50
# 10/10 [==============================] - 0s 6ms/step - loss: 8.0918e-04 - mean_absolute_error: 0.0224 - val_loss: 9.9383e-04 - val_mean_absolute_error: 0.0248
# Epoch 42/50
# 10/10 [==============================] - 0s 6ms/step - loss: 7.4010e-04 - mean_absolute_error: 0.0214 - val_loss: 9.2983e-04 - val_mean_absolute_error: 0.0240
# Epoch 43/50
# 10/10 [==============================] - 0s 8ms/step - loss: 6.8693e-04 - mean_absolute_error: 0.0208 - val_loss: 8.4553e-04 - val_mean_absolute_error: 0.0227
# Epoch 44/50
# 10/10 [==============================] - 0s 8ms/step - loss: 6.1598e-04 - mean_absolute_error: 0.0195 - val_loss: 7.8431e-04 - val_mean_absolute_error: 0.0220
# Epoch 45/50
# 10/10 [==============================] - 0s 7ms/step - loss: 5.7654e-04 - mean_absolute_error: 0.0188 - val_loss: 7.0605e-04 - val_mean_absolute_error: 0.0208
# Epoch 46/50
# 10/10 [==============================] - 0s 6ms/step - loss: 5.1974e-04 - mean_absolute_error: 0.0178 - val_loss: 6.4761e-04 - val_mean_absolute_error: 0.0198
# Epoch 47/50
# 10/10 [==============================] - 0s 7ms/step - loss: 4.7625e-04 - mean_absolute_error: 0.0171 - val_loss: 5.9175e-04 - val_mean_absolute_error: 0.0189
# Epoch 48/50
# 10/10 [==============================] - 0s 6ms/step - loss: 4.3466e-04 - mean_absolute_error: 0.0162 - val_loss: 5.4243e-04 - val_mean_absolute_error: 0.0181
# Epoch 49/50
# 10/10 [==============================] - 0s 8ms/step - loss: 3.9707e-04 - mean_absolute_error: 0.0155 - val_loss: 4.9127e-04 - val_mean_absolute_error: 0.0171
# Epoch 50/50
# 10/10 [==============================] - 0s 7ms/step - loss: 3.6149e-04 - mean_absolute_error: 0.0147 - val_loss: 4.5062e-04 - val_mean_absolute_error: 0.0163

# %%
tr_acc = history.history['mean_absolute_error']
tr_loss = history.history['loss']
val_acc = history.history['val_mean_absolute_error']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmin(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'

plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')

plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %%
ann_y_pred = ann.predict(X_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step

# %%
r2 = r2_score(y_test, y_pred)
print('R2 score:', r2)
# Out:
# R2 score: 0.999999977254054

# %%
ann.evaluate(X_test, y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 2.7606e-04 - mean_absolute_error: 0.0127
# [0.0002760603674687445, 0.012704048305749893]

# %%
ann.predict([[40, 70000.500, 9550,534000]])
# Out:
# 1/1 [==============================] - 0s 35ms/step
# array([[223273.44]], dtype=float32)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, label='Linear Regression')
plt.scatter(y_test, ann_y_pred, label='ANN')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='gray')
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Predicted vs. Actual Values')
plt.legend()
plt.show()

# %%
# Konversi variabel target kontinu menjadi label kategorikal (binning)
y_categorical = pd.cut(y.flatten(), bins=3, labels=['rendah', 'sedang', 'tinggi'])

# %%
# Bagi data menjadi data latih dan data uji
X_train, X_test, y_train, y_test = train_test_split(X, y_categorical, test_size=0.2, random_state=42)

# %%
# Inisialisasi dan latih model klasifikasi
clf = DecisionTreeClassifier()
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
# Buat prediksi pada data uji
y_pred = clf.predict(X_test)

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Label yang diprediksi')
plt.ylabel('Label yang sebenarnya')
plt.title('Confusion Matrix')
plt.show()

# %%
y_pred = clf.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#       rendah       0.62      0.77      0.69        13
#       sedang       0.93      0.87      0.90        71
#       tinggi       0.82      0.88      0.85        16
#
#     accuracy                           0.86       100
#    macro avg       0.79      0.84      0.81       100
# weighted avg       0.87      0.86      0.86       100
